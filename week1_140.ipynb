# %% [markdown]
# <a href="https://colab.research.google.com/github/krupa-16/AI/blob/main/week1_140.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def print_board(board):
  for row in board:
      print(" | ".join(row))
def check_win(board, player):
    for row in board:
        if all([cell == player for cell in row]):
            return True
    for col in range(3):
        if all([board[row][col] == player for row in range(3)]):
            return True
    if (board[0][0] == player and board[1][1] == player and board[2][2] == player) or \
       (board[0][2] == player and board[1][1] == player and board[2][0] == player):
        return True
    return False
def check_draw(board):
    for row in board:
        for cell in row:
            if cell == ' ':
                return False
    return True
def play_game():
    board = [[' ' for _ in range(3)] for _ in range(3)]
    current_player = 'X'
    game_over = False
    print("Krupasham_1401")
    print_board(board)
    while not game_over:
        try:
            print(f"Player {current_player}'s turn.")
            row = int(input("Enter row (0, 1, or 2): "))
            col = int(input("Enter column (0, 1, or 2): "))
            if 0 <= row <= 2 and 0 <= col <= 2 and board[row][col] == ' ':
                board[row][col] = current_player
                print_board(board)
                if check_win(board, current_player):
                    print(f"Player {current_player} wins!")
                    game_over = True
                elif check_draw(board):
                    print("It's a draw!")
                    game_over = True
                else:
                    current_player = 'O' if current_player == 'X' else 'X'
            else:
                print("Invalid move. Please try again (row and column must be 0-2 and cell must be empty).")
        except ValueError:
            print("Invalid input. Please enter a number for row and column.")
        except IndexError:
            print("Invalid input. Row and column must be 0, 1, or 2.")

if __name__ == "__main__":
    play_game()
# Out:
# Krupasham_140
#   |   |
#   |   |
#   |   |
# Player X's turn.
# Enter row (0, 1, or 2): 0
# Enter column (0, 1, or 2): 0
# X |   |
#   |   |
#   |   |
# Player O's turn.
# Enter row (0, 1, or 2): 1
# Enter column (0, 1, or 2):
# Invalid input. Please enter a number for row and column.
# Player O's turn.
# Enter row (0, 1, or 2): 1
# Enter column (0, 1, or 2): 1
# X |   |
#   | O |
#   |   |
# Player X's turn.
# Enter row (0, 1, or 2): 1
# Enter column (0, 1, or 2): 0
# X |   |
# X | O |
#   |   |
# Player O's turn.
# Enter row (0, 1, or 2): 2
# Enter column (0, 1, or 2): 2
# X |   |
# X | O |
#   |   | O
# Player X's turn.
# Enter row (0, 1, or 2): 2
# Enter column (0, 1, or 2): 0
# X |   |
# X | O |
# X |   | O
# Player X wins!
